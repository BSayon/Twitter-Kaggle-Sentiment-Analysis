# %% [markdown]
# ## Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Data Gathering

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %%
train = df.copy()
train = train.set_index('textID')
train['Selected Text'] = 0
train.head()
# Out:
#                                                          text  \
# textID
# cb774db0d1                I`d have responded, if I were going
# 549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 088c60f138                          my boss is bullying me...
# 9642c003ef                     what interview! leave me alone
# 358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                                   selected_text sentiment  Selected Text
# textID
# cb774db0d1  I`d have responded, if I were going   neutral              0
# 549e992a42                             Sooo SAD  negative              0
# 088c60f138                          bullying me  negative              0
# 9642c003ef                       leave me alone  negative              0
# 358bd9e861                        Sons of ****,  negative              0

# %%
train['sentiment'].value_counts()
# Out:
# neutral     11118
# positive     8582
# negative     7781
# Name: sentiment, dtype: int64

# %%
train[train['sentiment']=='neutral']
# Out:
#                                                          text  \
# textID
# cb774db0d1                I`d have responded, if I were going
# 28b57f3990  http://www.dothebouncy.com/smf - some shameles...
# 50e14c0bb8                                         Soooo high
# e050245fbd                                        Both of you
# 2339a9b08b   as much as i love to be hopeful, i reckon the...
# ...                                                       ...
# a753a93e45  few grilled mushrooms and olives, feta cheese ...
# ac92790d8b              94 more days till BH comes back to LA
# 15bb120f57  i`m defying gravity. and nobody in alll of oz,...
# a208770a32   in spoke to you yesterday and u didnt respond...
# 6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                                 selected_text sentiment  \
# textID
# cb774db0d1                I`d have responded, if I were going   neutral
# 28b57f3990  http://www.dothebouncy.com/smf - some shameles...   neutral
# 50e14c0bb8                                         Soooo high   neutral
# e050245fbd                                        Both of you   neutral
# 2339a9b08b  as much as i love to be hopeful, i reckon the ...   neutral
# ...                                                       ...       ...
# a753a93e45  few grilled mushrooms and olives, feta cheese ...   neutral
# ac92790d8b              94 more days till BH comes back to LA   neutral
# 15bb120f57  i`m defying gravity. and nobody in alll of oz,...   neutral
# a208770a32  in spoke to you yesterday and u didnt respond ...   neutral
# 6f7127d9d7  All this flirting going on - The ATG smiles. Y...   neutral
#
#             Selected Text
# textID
# cb774db0d1              0
# 28b57f3990              0
# 50e14c0bb8              0
# e050245fbd              0
# 2339a9b08b              0
# ...                   ...
# a753a93e45              0
# ac92790d8b              0
# 15bb120f57              0
# a208770a32              0
# 6f7127d9d7              0
#
# [11118 rows x 4 columns]

# %%
for idx in train[train['sentiment']=='neutral'].index:
    train.loc[idx,'Selected Text'] = train.loc[idx,'text']

# %%
train[train['sentiment']=='neutral'].head()
# Out:
#                                                          text  \
# textID
# cb774db0d1                I`d have responded, if I were going
# 28b57f3990  http://www.dothebouncy.com/smf - some shameles...
# 50e14c0bb8                                         Soooo high
# e050245fbd                                        Both of you
# 2339a9b08b   as much as i love to be hopeful, i reckon the...
#
#                                                 selected_text sentiment  \
# textID
# cb774db0d1                I`d have responded, if I were going   neutral
# 28b57f3990  http://www.dothebouncy.com/smf - some shameles...   neutral
# 50e14c0bb8                                         Soooo high   neutral
# e050245fbd                                        Both of you   neutral
# 2339a9b08b  as much as i love to be hopeful, i reckon the ...   neutral
#
#                                                 Selected Text
# textID
# cb774db0d1                I`d have responded, if I were going
# 28b57f3990  http://www.dothebouncy.com/smf - some shameles...
# 50e14c0bb8                                         Soooo high
# e050245fbd                                        Both of you
# 2339a9b08b   as much as i love to be hopeful, i reckon the...

# %%
train[train['sentiment']=='positive'].head()
# Out:
#                                                          text  \
# textID
# 6e0c6d75b1  2am feedings for the baby are fun when he is a...
# fc2cbefa9d   Journey!? Wow... u just became cooler.  hehe....
# 16fab9f95b  I really really like the song Love Story by Ta...
# e48b0b8a23  Playing Ghost Online is really interesting. Th...
# e00c6ef376  the free fillin` app on my ipod is fun, im add...
#
#                                                 selected_text sentiment  \
# textID
# 6e0c6d75b1                                                fun  positive
# fc2cbefa9d                       Wow... u just became cooler.  positive
# 16fab9f95b                                               like  positive
# e48b0b8a23                                       interesting.  positive
# e00c6ef376  the free fillin` app on my ipod is fun, im add...  positive
#
#            Selected Text
# textID
# 6e0c6d75b1             0
# fc2cbefa9d             0
# 16fab9f95b             0
# e48b0b8a23             0
# e00c6ef376             0

# %%
train[train['sentiment']=='negative'].head()
# Out:
#                                                          text   selected_text  \
# textID
# 549e992a42      Sooo SAD I will miss you here in San Diego!!!        Sooo SAD
# 088c60f138                          my boss is bullying me...     bullying me
# 9642c003ef                     what interview! leave me alone  leave me alone
# 358bd9e861   Sons of ****, why couldn`t they put them on t...   Sons of ****,
# 74a76f6e0a       My Sharpie is running DANGERously low on ink     DANGERously
#
#            sentiment Selected Text
# textID
# 549e992a42  negative             0
# 088c60f138  negative             0
# 9642c003ef  negative             0
# 358bd9e861  negative             0
# 74a76f6e0a  negative             0

# %%
def text_token(text):
    wordnet = WordNetLemmatizer()
    STOPWORDS = set(stopwords.words("english"))
    token = nltk.word_tokenize(text)
    token = [wordnet.lemmatize(i) for i in token]
    token = [i for i in token if i.isalpha() and len(i)>2 and (i not in STOPWORDS)]
    return token

# %%
postive_data = train[train['sentiment']=='positive'].copy()
negative_data = train[train['sentiment']=='negative'].copy()
postive_data['Selected Text'] = postive_data['text'].apply(lambda x: text_token(x))
negative_data['Selected Text'] = negative_data['text'].apply(lambda x: text_token(x))
negative_data.head()
# Out:
#                                                          text   selected_text  \
# textID
# 549e992a42      Sooo SAD I will miss you here in San Diego!!!        Sooo SAD
# 088c60f138                          my boss is bullying me...     bullying me
# 9642c003ef                     what interview! leave me alone  leave me alone
# 358bd9e861   Sons of ****, why couldn`t they put them on t...   Sons of ****,
# 74a76f6e0a       My Sharpie is running DANGERously low on ink     DANGERously
#
#            sentiment                              Selected Text
# textID
# 549e992a42  negative              [Sooo, SAD, miss, San, Diego]
# 088c60f138  negative                            [bos, bullying]
# 9642c003ef  negative                  [interview, leave, alone]
# 358bd9e861  negative      [Sons, put, release, already, bought]
# 74a76f6e0a  negative  [Sharpie, running, DANGERously, low, ink]

# %%
postive_data.head()
# Out:
#                                                          text  \
# textID
# 6e0c6d75b1  2am feedings for the baby are fun when he is a...
# fc2cbefa9d   Journey!? Wow... u just became cooler.  hehe....
# 16fab9f95b  I really really like the song Love Story by Ta...
# e48b0b8a23  Playing Ghost Online is really interesting. Th...
# e00c6ef376  the free fillin` app on my ipod is fun, im add...
#
#                                                 selected_text sentiment  \
# textID
# 6e0c6d75b1                                                fun  positive
# fc2cbefa9d                       Wow... u just became cooler.  positive
# 16fab9f95b                                               like  positive
# e48b0b8a23                                       interesting.  positive
# e00c6ef376  the free fillin` app on my ipod is fun, im add...  positive
#
#                                                 Selected Text
# textID
# 6e0c6d75b1                   [feeding, baby, fun, smile, coo]
# fc2cbefa9d     [Journey, Wow, became, cooler, hehe, possible]
# 16fab9f95b  [really, really, like, song, Love, Story, Tayl...
# e48b0b8a23  [Playing, Ghost, Online, really, interesting, ...
# e00c6ef376           [free, fillin, app, ipod, fun, addicted]

# %% [markdown]
# ## Frequency Count and Bag of Words

# %%
freq_count = {}
for tokens in postive_data['Selected Text']:
    for word in tokens:
        if word not in freq_count:
            freq_count[word] = 1
        else:
            freq_count[word] += 1

# %%
for tokens in negative_data['Selected Text']:
    for word in tokens:
        if word not in freq_count:
            freq_count[word] = 1
        else:
            freq_count[word] += 1

# %%
for text in (postive_data['selected_text']):
    tokens = text_token(text)
    for word in tokens:
        if word not in freq_count:
            freq_count[word] = 1
        else:
            freq_count[word] += 1

# %%
for text in (negative_data['selected_text']):
    tokens = text_token(text)
    for word in tokens:
        if word not in freq_count:
            freq_count[word] = 1
        else:
            freq_count[word] += 1

# %%
freq_count = {k: v for k, v in sorted(freq_count.items(), key=lambda item: item[1], reverse=True)}
word_index_map = {v:k for k,v in enumerate(list(freq_count.keys())[:6000])}

# %%
def token_vector(token, label):
    fg = False
    x = np.zeros(len(word_index_map)+1)
    for word in token:
        if word in word_index_map:
            index = word_index_map[word]
            x[index] += 1
            fg = True
    if fg:
        x = x/x.sum()
    x[-1] = label
    return x

# %%
postive_data.head()
# Out:
#                                                          text  \
# textID
# 6e0c6d75b1  2am feedings for the baby are fun when he is a...
# fc2cbefa9d   Journey!? Wow... u just became cooler.  hehe....
# 16fab9f95b  I really really like the song Love Story by Ta...
# e48b0b8a23  Playing Ghost Online is really interesting. Th...
# e00c6ef376  the free fillin` app on my ipod is fun, im add...
#
#                                                 selected_text sentiment  \
# textID
# 6e0c6d75b1                                                fun  positive
# fc2cbefa9d                       Wow... u just became cooler.  positive
# 16fab9f95b                                               like  positive
# e48b0b8a23                                       interesting.  positive
# e00c6ef376  the free fillin` app on my ipod is fun, im add...  positive
#
#                                                 Selected Text
# textID
# 6e0c6d75b1                   [feeding, baby, fun, smile, coo]
# fc2cbefa9d     [Journey, Wow, became, cooler, hehe, possible]
# 16fab9f95b  [really, really, like, song, Love, Story, Tayl...
# e48b0b8a23  [Playing, Ghost, Online, really, interesting, ...
# e00c6ef376           [free, fillin, app, ipod, fun, addicted]

# %%
data = np.zeros((len(postive_data)+len(negative_data), len(word_index_map)+1))
index = 0
for idx in zip(postive_data['Selected Text'],postive_data['sentiment']):
    text = idx[0]
    label = idx[1]
    if label == 'positive':
        label = 1
    else:
        label = 0
    data[index,:] = token_vector(text, label)
    index += 1

# %%
for idx in zip(negative_data['Selected Text'],negative_data['sentiment']):
    text = idx[0]
    label = idx[1]
    if label == 'positive':
        label = 1
    else:
        label = 0
    data[index,:] = token_vector(text, label)
    index += 1

# %% [markdown]
# ## Modelling

# %%
X = data[:,:-1]
y = data[:,-1]

# %%
model = LogisticRegression()
model.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
for word,index in word_index_map.items():
    weight = model.coef_[0][index]
    if weight>0.5:
        print(word,":",weight)
# Out:
# good : 5.037425021938829
# day : 1.6516762432186793
# love : 8.891173493891047
# like : 0.6305964474960788
# Happy : 6.190974238576343
# great : 6.493091651463694
# fun : 4.664066193320727
# happy : 4.450631651542656
# http : 1.3138115434767044
# night : 2.509571749320958
# nice : 5.033862465636485
# thanks : 6.4314150851895855
# see : 1.163377069895879
# wish : 2.0357429701063903
# hope : 5.593484890179396
# Day : 3.776058322234853
# Thanks : 6.284437985943987
# new : 1.9920091231725585
# mother : 3.027506540220484
# awesome : 6.044885812241773
# lol : 2.0454958010483835
# better : 4.753599486697956
# Good : 5.607684934520692
# The : 0.9576133622353714
# morning : 2.828459665772743
# You : 2.542029691936805
# best : 4.256859261816706
# would : 1.4100202579070493
# look : 0.5496614212557139
# haha : 2.943964815440851
# mom : 2.197891144699309
# tomorrow : 0.6869332670929971
# weekend : 0.8851386696835621
# Mother : 2.5512505728889803
# cool : 3.9720954365221006
# though : 1.119352391877292
# could : 0.6970393364099227
# amazing : 4.673594995276395
# guy : 0.8277028002716315
# wait : 2.394322021110849
# show : 0.9803267167590146
# thank : 4.427488369638409
# pretty : 2.743206452606668
# movie : 0.8338929915405595
# everyone : 1.442326408301878
# excited : 4.141237479999172
# Hope : 3.393808601848291
# year : 0.7506778058011109
# sure : 1.3103450235294234
# soon : 1.5122723466395949
# ever : 0.9478672977937365
# Love : 3.7109880223778378
# cute : 3.9930989907846595
# Thank : 4.109626795672945
# song : 1.426866957279998
# glad : 3.971941839163336
# lot : 0.8357314965176411
# funny : 2.75804602099444
# made : 1.0025196516599575
# luck : 1.2558808089791347
# Have : 1.3236993493835296
# watching : 1.2648091240099726
# Mothers : 1.5717722803868992
# lovely : 3.1752517836600234
# beautiful : 3.0389019358886693
# looking : 0.7973967076257544
# help : 0.7474504693326812
# forward : 1.8982753869312738
# please : 1.3075745348673857
# HAPPY : 2.629657238666522
# start : 0.5095008998752086
# Loving : 1.0154286627849962
# simple : 0.5753967669209697
# app : 0.5793037264543913
# Thx : 0.8314574302270948
# Enjoying : 0.9277366070359949
# advice : 0.5440710980621518
# Beautiful : 0.5847089577268453
# fabulous : 0.7471244501760114
# ily : 1.1194087643814887
# hubby : 0.5513617473375868
# Amazing : 0.5029129705081028
# World : 0.8328048042867641
# GOOD : 0.9915246712704027
# partying : 0.5477655116475922
# anytime : 0.6100860594961673
# smart : 0.5858519166890592
# awsome : 0.615197378219418
# recommend : 0.5977740339754638
# Cheers : 0.5699153717814934
# KNOW : 0.5121101765565829
# thnx : 0.7943007112957529
# followfriday : 0.5604742191930128
# sandwich : 0.7229883765413354
# Chillin : 0.8804886760188617
# bbq : 0.5799104328022765
# Perfect : 0.5381042330089119
# relax : 0.7730060183107711
# trek : 0.6641938521125235
# talented : 0.5132626325183028
# Goodmorning : 0.8617152415067838
# PLEASE : 0.5138006169626335
# Rock : 0.527742862946366
# Excited : 0.8438956069672835
# Luv : 0.5491299624731533
# Eating : 0.7850694337721397
# goodness : 0.7413083305997229
# Yum : 0.7183273703190622
# thankyou : 0.8310934389601548
# Always : 0.5512591610571251
# latest : 0.6190871730365897
# Tell : 0.5040336846217475
# Ben : 0.6462432131175566
# Mondays : 0.8534415102395299
# Check : 0.5986638022685616
# THANK : 0.6884292540257527
# crush : 0.8239581474044984
# JONAS : 0.5166439215224023
# truth : 0.7128164494938796
# mornin : 0.6321773200264517
# smiling : 0.5097583410989839
# loud : 0.5626852567370284
# woo : 0.5890066756785135
# THANKS : 1.0945864588141907
# Wishes : 0.5701320745712689
# Relaxing : 0.9210021989020701
# NICE : 0.7472475373957307
# lovin : 0.6077475342144498
# curious : 0.5284302096258935
# Chilling : 0.6508242175973058
# Hugs : 0.5323665528545992
# popular : 0.5059203208902651
# chilling : 0.5844481422687225
# massage : 0.5259622250345016
# Hehe : 0.7677814504408554
# LoL : 0.5829677598958162
# Goood : 0.8119543507906576
# SUMMER : 0.5098766786158889
# awesomeness : 0.5436371828558126
# sweetheart : 0.6632578022953268
# Smile : 0.510268186491662
# HaPPy : 0.5319215443030262
# Patience : 0.5420792731394338
# goood : 0.7129933934424674
# goodmorning : 0.7129933934424674
# woot : 0.5191923463702349

# %%
def token_text(tokens, label):
    threshold = 0.5
    text = []
    for word in tokens:
        if word in word_index_map:
            index = word_index_map[word]
            weight = model.coef_[0][index]
            if label == 1:
                if weight>threshold:
                    text.append(word)
            if label == 0:
                if weight<-threshold:
                    text.append(word)
    if len(text) == 0:
        return " ".join(tokens)
    return " ".join(text)

# %%
token_text(['day','with','you','bad','boy'],0)
# Out:
# 'bad'

# %%
postive_data['Selected Text'] = postive_data['Selected Text'].apply(lambda x: token_text(x,1))
negative_data['Selected Text'] = negative_data['Selected Text'].apply(lambda x: token_text(x,0))

# %%
postive_data
# Out:
#                                                          text  \
# textID
# 6e0c6d75b1  2am feedings for the baby are fun when he is a...
# fc2cbefa9d   Journey!? Wow... u just became cooler.  hehe....
# 16fab9f95b  I really really like the song Love Story by Ta...
# e48b0b8a23  Playing Ghost Online is really interesting. Th...
# e00c6ef376  the free fillin` app on my ipod is fun, im add...
# ...                                                       ...
# 432e6de6c9  morning twit-friends! welcome to my new followers
# 8f14bb2715  So I get up early and I feel good about the da...
# b78ec00df5                                     enjoy ur night
# f67aae2310   Yay good for both of you. Enjoy the break - y...
# ed167662a5                         But it was worth it  ****.
#
#                                                 selected_text sentiment  \
# textID
# 6e0c6d75b1                                                fun  positive
# fc2cbefa9d                       Wow... u just became cooler.  positive
# 16fab9f95b                                               like  positive
# e48b0b8a23                                       interesting.  positive
# e00c6ef376  the free fillin` app on my ipod is fun, im add...  positive
# ...                                                       ...       ...
# 432e6de6c9                                            welcome  positive
# 8f14bb2715                                     I feel good ab  positive
# b78ec00df5                                              enjoy  positive
# f67aae2310                          Yay good for both of you.  positive
# ed167662a5                         But it was worth it  ****.  positive
#
#                          Selected Text
# textID
# 6e0c6d75b1                   fun smile
# fc2cbefa9d                    Wow hehe
# 16fab9f95b              like song Love
# e48b0b8a23    interesting The new wait
# e00c6ef376                free app fun
# ...                                ...
# 432e6de6c9         morning welcome new
# 8f14bb2715            good day alright
# b78ec00df5                 enjoy night
# f67aae2310  Yay good Enjoy weekend hun
# ed167662a5                       worth
#
# [8582 rows x 4 columns]

# %%
postive_data[postive_data['selected_text']==postive_data['Selected Text']]
# Out:
#                                                          text selected_text  \
# textID
# 6ce4a4954b  juss came backk from Berkeleyy ; omg its madd ...           fun
# 7d8c4c11e4  i hope unni will make the audition . fighting ...          hope
# fa2654e730                                           Chilliin      Chilliin
# 92e1b6846e     We saw that in none 3D - the baddie`s the best          best
# 2207d982bc                   4am. And Im on the beach. Pretty        Pretty
# ...                                                       ...           ...
# 45154b041d                         ok bye alex have fun today           fun
# bda2ce839a  _  it`s on again right now!! aah I love demi l...          love
# 25ae8c8eff   That`s more than ok. Personally I`m very good...          good
# 47c474aaf1                                        Good choice          Good
# 13e1519ce3                          good as, cya in melbourne          good
#
#            sentiment Selected Text
# textID
# 6ce4a4954b  positive           fun
# 7d8c4c11e4  positive          hope
# fa2654e730  positive      Chilliin
# 92e1b6846e  positive          best
# 2207d982bc  positive        Pretty
# ...              ...           ...
# 45154b041d  positive           fun
# bda2ce839a  positive          love
# 25ae8c8eff  positive          good
# 47c474aaf1  positive          Good
# 13e1519ce3  positive          good
#
# [627 rows x 4 columns]

# %%
negative_data[negative_data['selected_text']==negative_data['Selected Text']]
# Out:
#                                                          text  selected_text  \
# textID
# 447dc22c81       hemp cloth is marvelous but unfortunately no  unfortunately
# 02c004bc2d                                I am tres depressed      depressed
# 05a0e60f99                            I`m sorry to hear that.          sorry
# 1f581d48bc                          Sorry RB is on PS3 for me          Sorry
# cf888f0df3          I`m taking a twitter break. Cell is dying          dying
# ...                                                       ...            ...
# 0828ad29fe                                  _123 i cant sleep     cant sleep
# 83d3323ada  Screen On The Green started yesterday!!!ahhh! ...         missed
# 836b055959  Twitter`s being lame and won`t post my twitpic...           lame
# 0161b55ae1                                      just threw up          threw
# fa318ab83c        My blackberry is soon approaching her death          death
#
#            sentiment  Selected Text
# textID
# 447dc22c81  negative  unfortunately
# 02c004bc2d  negative      depressed
# 05a0e60f99  negative          sorry
# 1f581d48bc  negative          Sorry
# cf888f0df3  negative          dying
# ...              ...            ...
# 0828ad29fe  negative     cant sleep
# 83d3323ada  negative         missed
# 836b055959  negative           lame
# 0161b55ae1  negative          threw
# fa318ab83c  negative          death
#
# [425 rows x 4 columns]

# %% [markdown]
# ## Test Data

# %%
test = pd.read_csv('test.csv', index_col='textID')
test['selected_text'] = test['text']
test.head()
# Out:
#                                                          text sentiment  \
# textID
# f87dea47db  Last session of the day  http://twitpic.com/67ezh   neutral
# 96d74cb729   Shanghai is also really exciting (precisely -...  positive
# eee518ae67  Recession hit Veronique Branquinho, she has to...  negative
# 01082688c6                                        happy bday!  positive
# 33987a8ee5             http://twitpic.com/4w75p - I like it!!  positive
#
#                                                 selected_text
# textID
# f87dea47db  Last session of the day  http://twitpic.com/67ezh
# 96d74cb729   Shanghai is also really exciting (precisely -...
# eee518ae67  Recession hit Veronique Branquinho, she has to...
# 01082688c6                                        happy bday!
# 33987a8ee5             http://twitpic.com/4w75p - I like it!!

# %%
postive_test = test[test['sentiment']=='positive']
negative_test = test[test['sentiment']=='negative']
postive_test['selected_text'] = postive_test['text'].apply(lambda x: text_token(x))
negative_test['selected_text'] = negative_test['text'].apply(lambda x: text_token(x))
# Out:
# D:\software\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\software\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
postive_test.head()
# Out:
#                                                          text sentiment  \
# textID
# 96d74cb729   Shanghai is also really exciting (precisely -...  positive
# 01082688c6                                        happy bday!  positive
# 33987a8ee5             http://twitpic.com/4w75p - I like it!!  positive
# 726e501993                    that`s great!! weee!! visitors!  positive
# 33f19050cf   you guys didn`t say hi or answer my questions...  positive
#
#                                                 selected_text
# textID
# 96d74cb729  [Shanghai, also, really, exciting, precisely, ...
# 01082688c6                                      [happy, bday]
# 33987a8ee5                                       [http, like]
# 726e501993                             [great, weee, visitor]
# 33f19050cf  [guy, say, answer, question, yesterday, nice, ...

# %%
negative_test.head()
# Out:
#                                                          text sentiment  \
# textID
# eee518ae67  Recession hit Veronique Branquinho, she has to...  negative
# 261932614e            I THINK EVERYONE HATES ME ON HERE   lol  negative
# afa11da83f   soooooo wish i could, but im in school and my...  negative
# 24c92644a4  My bike was put on hold...should have known th...  negative
# 5c1e0b61a1  I`m in VA for the weekend, my youngest son tur...  negative
#
#                                                 selected_text
# textID
# eee518ae67  [Recession, hit, Veronique, Branquinho, quit, ...
# 261932614e                [THINK, EVERYONE, HATES, HERE, lol]
# afa11da83f  [soooooo, wish, could, school, myspace, comple...
# 24c92644a4      [bike, put, hold, known, argh, total, bummer]
# 5c1e0b61a1  [weekend, youngest, son, turn, tomorrow, make,...

# %%
for tokens in postive_test['selected_text']:
    for word in tokens:
        if word not in freq_count:
            freq_count[word] = 1
        else:
            freq_count[word] += 1
for tokens in negative_test['selected_text']:
    for word in tokens:
        if word not in freq_count:
            freq_count[word] = 1
        else:
            freq_count[word] += 1

# %%
freq_count = {k: v for k, v in sorted(freq_count.items(), key=lambda item: item[1], reverse=True)}
word_index_map = {v:k for k,v in enumerate(list(freq_count.keys())[:6000])}

# %%
postive_test['selected_text'] = postive_test['selected_text'].apply(lambda x: token_text(x,1))
negative_test['selected_text'] = negative_test['selected_text'].apply(lambda x: token_text(x,0))
# Out:
# D:\software\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# D:\software\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
negative_test.head()
# Out:
#                                                          text sentiment  \
# textID
# eee518ae67  Recession hit Veronique Branquinho, she has to...  negative
# 261932614e            I THINK EVERYONE HATES ME ON HERE   lol  negative
# afa11da83f   soooooo wish i could, but im in school and my...  negative
# 24c92644a4  My bike was put on hold...should have known th...  negative
# 5c1e0b61a1  I`m in VA for the weekend, my youngest son tur...  negative
#
#                             selected_text
# textID
# eee518ae67                      hit shame
# 261932614e  THINK EVERYONE HATES HERE lol
# afa11da83f          could myspace blocked
# 24c92644a4                       put argh
# 5c1e0b61a1          turn tomorrow sad big

# %%
test[test['sentiment']=='positive'] = postive_test
test[test['sentiment']=='negative'] = negative_test

# %%
test.head()
# Out:
#                                                          text sentiment  \
# textID
# f87dea47db  Last session of the day  http://twitpic.com/67ezh   neutral
# 96d74cb729   Shanghai is also really exciting (precisely -...  positive
# eee518ae67  Recession hit Veronique Branquinho, she has to...  negative
# 01082688c6                                        happy bday!  positive
# 33987a8ee5             http://twitpic.com/4w75p - I like it!!  positive
#
#                                                 selected_text
# textID
# f87dea47db  Last session of the day  http://twitpic.com/67ezh
# 96d74cb729                                          also Good
# eee518ae67                                          hit shame
# 01082688c6                                              happy
# 33987a8ee5                                          http like

# %% [markdown]
# ## Saving the csv file

# %%
test.loc[:,['selected_text']].to_csv('submission.csv')

# %% [markdown]
# ## Rough Space

# %%
train[train['sentiment']=='positive'] = postive_data
train[train['sentiment']=='negative'] = negative_data

# %%
train[train['selected_text']==train['Selected Text']].groupby(by='sentiment').count()
# Out:
#            text  selected_text  Selected Text
# sentiment
# negative    425            425            425
# neutral    5930           5930           5930
# positive    627            627            627

# %%
train.head()
# Out:
#                                                          text  \
# textID
# cb774db0d1                I`d have responded, if I were going
# 549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 088c60f138                          my boss is bullying me...
# 9642c003ef                     what interview! leave me alone
# 358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                                   selected_text sentiment  \
# textID
# cb774db0d1  I`d have responded, if I were going   neutral
# 549e992a42                             Sooo SAD  negative
# 088c60f138                          bullying me  negative
# 9642c003ef                       leave me alone  negative
# 358bd9e861                        Sons of ****,  negative
#
#                                    Selected Text
# textID
# cb774db0d1   I`d have responded, if I were going
# 549e992a42                              SAD miss
# 088c60f138                                   bos
# 9642c003ef                           leave alone
# 358bd9e861                               already
